# %%
import os
import sys

if not hasattr(sys.modules[__name__], "cwd_changed"):
    os.chdir(os.path.dirname(os.path.dirname(os.path.abspath(__name__))))
    sys.modules[__name__].cwd_changed = True

# from src.pipeline import *

import pickle

# %%
with open("results/hc/binary_data.pkl", "rb") as f:
    results_hc = pickle.load(f)

# %%
eval_metrics = results_hc[0].eval_metrics

# %%
results_hc[0].metadata_by_id[110]
# Out:
#        Combs      Type
# 0  [5, 8, 7]       XOR
# 1     [2, 4]  Pairwise
# 2     [5, 9]  Pairwise
# 3  [8, 9, 0]       XOR

# %%
type(eval_metrics["BIC"][0])
# Out:
# numpy.float64

# %%
# long = all_results[0].eval_metrics
from utils.results import plot_final_heatmap
mapping="data/experiments/RQ1/binary_grid/grid_mapping.csv"
metric = "Recall (Synergy)"   # or "F1 (Collider)", "SHD", "Recall (Synergy)"
# x_col="samples"
x_col="n_syn"
y_col="p_noise"
# Close prior figures to avoid stacking / memory leaks
# plt.close("all")

# for metric in ["SHD", "F1 (Collider)", "Recall (Synergy)", "Recall (Collider)"]:

print(f"Plotting heatmap for {results} samples...")
fig, axes = plot_final_heatmap(
    subset_results_by_samples(results_by_label, results),
    mapping=mapping,
    subset_metrics=[metric],
    plot_metric=metric,
x_col=x_col,
y_col=y_col,
)

# fig, axes = plot_final_heatmap(

#     subset_results_by_samples(results_by_label, 1000),
#     mapping=mapping,
#     subset_metrics=[metric],
#     plot_metric=metric,
#     x_col=x_col,
#     y_col=y_col,
# )

# fig.suptitle(f"Final Heatmap: {metric} by {x_col} and {y_col} (1000 samples)")
# fig.tight_layout()
# Out:
# Plotting heatmap for 500 samples...
# Plotting heatmap for 1000 samples...
# Plotting heatmap for 2000 samples...
# Plotting heatmap for 5000 samples...
# Plotting heatmap for 10000 samples...

# %%
### Jointpmf

# %%
results_by_label_jpmf = load_results("jpmf_grid", ["hc", "ges", "ea_fg"])

# %%
from utils.results import plot_final_heatmap
mapping="data/experiments/RQ1/jpmf_grid/grid_mapping.csv"
metric = "Synergistic Colliders Found"   # or "F1 (Collider)", "SHD", "Recall (Synergy)"
# x_col="samples"
# x_col="pairs_probs"
x_col="target_mi"
y_col="syn_cutoff"

# Close prior figures to avoid stacking / memory leaks
# plt.close("all")

# for metric in ["SHD", "F1 (Collider)", "Recall (Synergy)", "Recall (Collider)"]:

for results in [500,1000, 2000, 5000, 10000]:
    print(f"Plotting heatmap for {results} samples...")
    fig, axes = plot_final_heatmap(
        subset_results_by_samples(results_by_label_jpmf, results),
        mapping=mapping,
        subset_metrics=[metric, x_col],
        plot_metric=metric,
    x_col=x_col,
    y_col=y_col,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from utils.results import plot_final_heatmap
#       2 mapping="data/experiments/RQ1/jpmf_grid/grid_mapping.csv"
#       3 metric = "Synergistic Colliders Found"   # or "F1 (Collider)", "SHD", "Recall (Synergy)"
#
# File d:\Thesis\Repository\utils\results.py:3
#       1 import os
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 import matplotlib.ticker as mticker
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)
#     148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
# ...

# %%
from utils.results import plot_final_heatmap
mapping="data/experiments/RQ1/jpmf_grid/grid_mapping.csv"
metric = "Recall (Synergy)"   # or "F1 (Collider)", "SHD", "Recall (Synergy)"
# x_col="samples"
# x_col="target_mi"
x_col="pairs_probs"
y_col="syn_cutoff"


# Close prior figures to avoid stacking / memory leaks
# plt.close("all")

# for metric in ["SHD", "F1 (Collider)", "Recall (Synergy)", "Recall (Collider)"]:

for results in [500,1000, 2000, 5000, 10000]:
    print(f"Plotting heatmap for {results} samples...")
    fig, axes = plot_final_heatmap(
        subset_results_by_samples(results_by_label_jpmf, results),
        mapping=mapping,
        subset_metrics=[metric, x_col],
        plot_metric=metric,
    x_col=x_col,
    y_col=y_col,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from utils.results import plot_final_heatmap
#       2 mapping="data/experiments/RQ1/jpmf_grid/grid_mapping.csv"
#       3 metric = "Recall (Synergy)"   # or "F1 (Collider)", "SHD", "Recall (Synergy)"
#
# File d:\Thesis\Repository\utils\results.py:3
#       1 import os
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 import matplotlib.ticker as mticker
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)
#     148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
# ...
